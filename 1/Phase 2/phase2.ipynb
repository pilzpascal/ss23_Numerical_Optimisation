# %% [markdown]
# # Project 1, Phase 2

# %% [markdown]
# Leon Alexander Akkad
# Dominik Baron
# Matthias Guzmits
# Pascal Pilz
# Aaron Zettler

# %% [markdown]
# <div class="alert alert-warning">
#     <h2>Auxiliary Percentage</h2>
#     We were able to solve all <b>6/6</b> problems.
# </div>

# %%
import numpy as np
import pandas as pd
from approx_gradient import approximate_gradient

# %% [markdown]
# ## Newton method with Hessian modification

# %%
from NM_w_hessian_mod import function_1, function_2, eig_val_mod, add_id, no_mod, newtons_method_hessian_mod
from approx_gradient import approximate_gradient, approximate_hessian

start_points = {'function_1': np.array([[1.2, 1.2], [-1.2, 1], [0.2, 0.8]]),
                'function_2': np.array([[-0.2, 1.2], [3.8, 0.1], [1.9, 0.6]])}
functions = {'function_1': function_1(),
             'function_2': function_2()}


for mod_method in [eig_val_mod, no_mod]:
    print('='*80)
    print('='*80)
    print('='*80)
    print()
    if mod_method == eig_val_mod:
        print(f'Using Eigenvalue Modifiction.')
        print()
    else:
        print(f'Using no modifcation, i.e. normal Newton Method.')
        print()
    for grad_method in ['symbolic', 'numeric']:
        print('='*70)
        print('='*70)
        print()
        print(f'using {grad_method} method to get the gradient')
        print()
        for function in functions:
            f, grad_f, hess_f = functions[function]
            if grad_method == 'numeric':
                grad_f = lambda x: approximate_gradient(f, x)
                hess_f = lambda x: approximate_hessian(f, x)
            print('='*60)
            print()
            print(f'{function}: {f.__doc__}')
            print()
            for x_0 in start_points[function]:
                print('-'*50)
                print(f'starting point: {x_0}')
                print()
                x_fin, p_fin, a_fin, n_iter = newtons_method_hessian_mod(
                    x_0, f, grad_f, hess_f, stop_crit=1e-6, print_interval=False, hess_modifier=mod_method)
                result = x_fin[-1]
                print(f'iterations:   {n_iter}')
                print(f'norm of grad: {np.linalg.norm(grad_f(result))}')
                print(f'endpoint:     {result}')
                print()
# Out:
# ================================================================================
# ================================================================================
# ================================================================================
#
# Using Eigenvalue Modifiction.
#
# ======================================================================
# ======================================================================
#
# using symbolic method to get the gradient
#
# ============================================================
#
# function_1: 100*(x[1] - x[0]**2)**2 + (1 - x[0])**2
#
# --------------------------------------------------
# starting point: [1.2 1.2]
#
# [[1250. -480.]
#  [-480.  200.]]
# [-115.6   48. ]
# [[1146.18325698 -478.36734694]
#  [-478.36734694  200.        ]]
# [-0.3998062   0.00333195]
# [[ 818.29312992 -400.26024856]
#  [-400.26024856  200.        ]]
# [-15.26302143   7.62589852]
# [[ 802.92057877 -400.23007795]
#  [-400.23007795  200.        ]]
# [-1.15266675e-03  1.13783156e-06]
# [[ 802.00013339 -400.00000026]
#  [-400.00000026  200.        ]]
# [-1.32340671e-04  6.61696811e-05]
# iterations:   5
# norm of grad: 1.1368683772161603e-13
# endpoint:     [1. 1.]
#
# --------------------------------------------------
# starting point: [-1.2  1. ]
#
# [[1330.  480.]
#  [ 480.  200.]]
# [215.6  88. ]
# [[1107.2725666   470.11235955]
#  [ 470.11235955  200.        ]]
# [4.63781641 0.12220679]
# [[1970.82670983 -305.24594847]
#  [-305.24594847  200.        ]]
# [-1146.45069037   751.47563227]
# [[ 468.25993932 -305.37187155]
#  [-305.37187155  200.        ]]
# [4.73110379e-01 1.98207784e-05]
# [[ 824.37781709 -399.99812443]
#  [-399.99812443  200.        ]]
# [-22.38520499  11.19265967]
# [[ 801.99311306 -399.99827826]
#  [-399.99827826  200.        ]]
# [8.60863344e-06 2.95541369e-11]
# iterations:   6
# norm of grad: 8.285705989878098e-09
# endpoint:     [1. 1.]
#
# --------------------------------------------------
# starting point: [0.2 0.8]
#
# [[281.37657846  11.27923292]
#  [ 11.27923292 215.11108503]]
# [  62.4 -152. ]
# [[ 213.56984265 -180.24751729]
#  [-180.24751729  200.        ]]
# [-21.03743753  24.56200261]
# [[ 180.49572328 -188.84435871]
#  [-188.84435871  200.        ]]
# [0.96854901 0.0923821 ]
# [[ 825.57580584 -382.14269335]
#  [-382.14269335  200.        ]]
# [-89.1511739   46.70530772]
# [[ 733.59669832 -382.51701871]
#  [-382.51701871  200.        ]]
# [0.08707992 0.00017515]
# [[ 802.75162264 -399.9969384 ]
#  [-399.9969384   200.        ]]
# [-0.76384783  0.38193449]
# [[ 801.9966154  -399.99915385]
#  [-399.99915385  200.        ]]
# [4.21849921e-06 6.13524787e-09]
# iterations:   7
# norm of grad: 2.0011564815486763e-09
# endpoint:     [1. 1.]
#
# ============================================================
#
# function_2: 150*(x[0]*x[1])**2 + (0.5*x[0] + 2*x[1] - 2)**2
#
# --------------------------------------------------
# starting point: [-0.2  1.2]
#
# [[ 436.75955947 -128.30174284]
#  [-128.30174284   64.05203185]]
# [ 86.1 -15.6]
# [[737.86388266 100.24205587]
#  [100.24205587  16.09945814]]
# [-78.70441164  -9.95044284]
# [[1045.85253719  -45.20687985]
#  [ -45.20687985    8.53295167]]
# [42.34786592 -7.84402553]
# [[272.74380321 -21.53030305]
#  [-21.53030305   8.50843688]]
# [11.32303426 -0.02294684]
# [[350.75885004   8.77117278]
#  [  8.77117278   8.03272493]]
# [-3.82447098 -0.70043092]
# [[302.37361756   2.88864701]
#  [  2.88864701   8.00065399]]
# [-0.45268274 -0.02855167]
# [[300.54753216   2.00504414]
#  [  2.00504414   8.00000002]]
# [-0.00268491 -0.00065057]
# iterations:   7
# norm of grad: 4.000702816117235e-07
# endpoint:     [1.31403113e-09 1.00000000e+00]
#
# --------------------------------------------------
# starting point: [3.8 0.1]
#
# [[  20.78096702  229.08601313]
#  [ 229.08601313 4340.04834058]]
# [ -11.5 -433.6]
# [[   9.28505879 -209.63645439]
#  [-209.63645439 7843.3459513 ]]
# [ -7.73419567 539.6241782 ]
# [[4.50113824e+00 2.02591983e+02]
#  [2.02591983e+02 1.44039826e+04]]
# [  -6.40285747 -701.1755949 ]
# [[ 1.31944311e+00 -1.59644495e+02]
#  [-1.59644495e+02  2.44246239e+04]]
# [ -4.86472852 719.35569182]
# [[ 5.05466266e-01 -1.95941601e+01]
#  [-1.95941601e+01  2.13346133e+04]]
# [-2.25325724 82.20595646]
# [[ 5.06124874e-01 -8.74650111e+00]
#  [-8.74650111e+00  4.72186403e+03]]
# [2.78441917e-03 2.14075357e+01]
# [[5.00009264e-01 2.42707219e+00]
#  [2.42707219e+00 4.93013571e+03]]
# [-0.02567408 -0.96748916]
# [[5.00000006e-01 2.01044886e+00]
#  [2.01044886e+00 4.80813164e+03]]
# [-3.61550517e-05 -2.10425443e-02]
# iterations:   8
# norm of grad: 5.730882206086452e-07
# endpoint:     [4.00000005e+00 1.00345538e-10]
#
# --------------------------------------------------
# starting point: [1.9 0.6]
#
# [[ 494.56934381  487.61605199]
#  [ 487.61605199 1192.94073023]]
# [-205.35 -650.4 ]
# [[ 1.03664435e+00 -3.45750696e+01]
#  [-3.45750696e+01  1.33719829e+03]]
# [ 0.47565335 42.5233318 ]
# [[  173.82330527  2269.72581515]
#  [ 2269.72581515 51855.64902284]]
# [  -333.00702625 -14969.42513779]
# [[ 7.48384138e+01 -1.98545582e+03]
#  [-1.98545582e+03  9.15945961e+04]]
# [ -195.00839826 17349.52914995]
# [[3.14155440e+01 1.71321242e+03]
#  [1.71321242e+03 1.61012972e+05]]
# [  -115.19777773 -19863.90461248]
# [[ 1.21783014e+01 -1.42026520e+03]
#  [-1.42026520e+03  2.78325100e+05]]
# [  -68.42154627 21608.5443705 ]
# [[3.42129251e+00 1.00945602e+03]
#  [1.00945602e+03 4.55019486e+05]]
# [   -39.27693231 -19687.97203347]
# [[ 5.21240344e-01 -2.13416330e+02]
#  [-2.13416330e+02  5.46187900e+05]]
# [ -20.22370745 4518.47464046]
# [[ 0.58280421 -3.10530891]
#  [-3.10530891 86.69219461]]
# [1.73473865 8.41595657]
# [[ 114.38930482  673.99377235]
#  [ 673.99377235 7007.7300195 ]]
# [  -80.9967497  -1649.18367393]
# [[   46.68371082  -574.95201878]
#  [ -574.95201878 12280.91492454]]
# [ -44.54400334 1847.42326315]
# [[2.02242303e+01 5.07376004e+02]
#  [5.07376004e+02 2.17756886e+04]]
# [  -27.48203355 -2163.92952857]
# [[ 8.01318578e+00 -4.30008837e+02]
#  [-4.30008837e+02  3.79638487e+04]]
# [ -17.32747037 2416.05310782]
# [[2.23087945e+00 3.12224850e+02]
#  [3.12224850e+02 6.25838413e+04]]
# [  -10.8461172  -2261.43291161]
# [[ 5.03811446e-01 -3.02720923e+01]
#  [-3.02720923e+01  6.83211752e+04]]
# [ -5.59542742 221.34261483]
# [[ 5.08400369e-01 -1.03192242e+01]
#  [-1.03192242e+01  4.52456624e+03]]
# [ 0.03793603 24.18206783]
# [[5.00072285e-01 3.19931161e+00]
#  [3.19931161e+00 4.98258440e+03]]
# [-0.03732299 -2.58996924]
# [[5.00000087e-01 2.04089713e+00]
#  [2.04089713e+00 4.80917615e+03]]
# [-0.00027944 -0.08292065]
# [[5.00000000e-01 2.00000931e+00]
#  [2.00000931e+00 4.80800163e+03]]
# [-3.48294510e-07 -2.00084487e-05]
# iterations:   19
# norm of grad: 6.3398437055333644e-12
# endpoint:     [4.00000000e+00 1.30565531e-15]
#
# ======================================================================
# ======================================================================
#
# using numeric method to get the gradient
#
# ============================================================
#
# function_1: 100*(x[1] - x[0]**2)**2 + (1 - x[0])**2
#
# --------------------------------------------------
# starting point: [1.2 1.2]
#
# [[1250.00054751 -480.00003972]
#  [-480.00003972  200.00001655]]
# [-115.60062499   47.9999    ]
# [[1146.16663903 -478.36382425]
#  [-478.36382425  199.9999992 ]]
# [-0.40064473  0.00335032]
# [[ 817.73958438 -400.10724595]
#  [-400.10724595  200.00000267]]
# [-15.31548051   7.6551152 ]
# [[ 802.32335375 -400.08077978]
#  [-400.08077978  199.99999997]]
# [-1.00705647e-03  9.77221171e-07]
# [[ 801.5194925  -399.87977982]
#  [-399.87977982  200.00000001]]
# [-1.00571204e-04  5.05012780e-05]
# iterations:   5
# norm of grad: 1.0591508027964967e-10
# endpoint:     [0.99969965 0.99939889]
#
# --------------------------------------------------
# starting point: [-1.2  1. ]
#
# [[1330.00099822  480.00181607]
#  [ 480.00181607  200.0017929 ]]
# [215.59933498  87.99989999]
# [[1107.2689432   470.11106119]
#  [ 470.11106119  200.00023859]]
# [4.63927896 0.12296778]
# [[1961.32532437 -303.88491723]
#  [-303.88491723  199.97514755]]
# [-1137.2838153    748.82549575]
# [[ 464.04772559 -304.05052608]
#  [-304.05052608  200.00000094]]
# [ 0.62081422 -0.09304434]
# [[ 869.39275223 -409.74686144]
#  [-409.74686144  200.00000267]]
# [-28.65920144  13.96463648]
# [[ 838.76217774 -409.08700513]
#  [-409.08700513  199.99999996]]
# [-0.04717257  0.00054444]
# [[ 801.73672946 -399.88114702]
#  [-399.88114702  200.00000001]]
# [-0.21181315  0.10593478]
# iterations:   7
# norm of grad: 5.220184635677414e-07
# endpoint:     [0.99969991 0.99939941]
#
# --------------------------------------------------
# starting point: [0.2 0.8]
#
# [[281.37119274  11.27794131]
#  [ 11.27794131 215.11513437]]
# [  62.40013499 -152.00010001]
# [[ 213.56544311 -180.24803872]
#  [-180.24803872  199.99996104]]
# [-21.03522499  24.55925022]
# [[ 180.49568784 -188.84425967]
#  [-188.84425967  200.00000267]]
# [0.9683828  0.09236315]
# [[ 825.34956647 -382.09524433]
#  [-382.09524433  200.00001655]]
# [-89.09676635  46.6824358 ]
# [[ 733.41009031 -382.46817773]
#  [-382.46817773  199.99999996]]
# [0.08676127 0.00017774]
# [[ 802.29282046 -399.88357703]
#  [-399.88357703  199.99999999]]
# [-0.75803861  0.37912016]
# [[ 801.52357373 -399.88082569]
#  [-399.88082569  200.00000001]]
# [-4.84976100e-06  9.42689259e-09]
# iterations:   7
# norm of grad: 1.23365993100326e-09
# endpoint:     [0.99969965 0.99939889]
#
# ============================================================
#
# function_2: 150*(x[0]*x[1])**2 + (0.5*x[0] + 2*x[1] - 2)**2
#
# --------------------------------------------------
# starting point: [-0.2  1.2]
#
# [[ 436.75983652 -128.30187844]
#  [-128.30187844   64.0521806 ]]
# [ 86.09978375 -15.60001   ]
# [[737.86070188 100.2404876 ]
#  [100.2404876   16.0989235 ]]
# [-78.7031877   -9.95023981]
# [[1045.83242067  -45.20439578]
#  [ -45.20439578    8.5328411 ]]
# [42.3445743  -7.84379463]
# [[272.74106584 -21.52931999]
#  [-21.52931999   8.50840232]]
# [11.32239053 -0.02287858]
# [[350.7531661    8.77037679]
#  [  8.77037679   8.03272032]]
# [-3.82416911 -0.70035403]
# [[302.37328548   2.8881607 ]
#  [  2.8881607    8.00065328]]
# [-0.45258827 -0.02854892]
# [[300.54728728   2.00474256]
#  [  2.00474256   8.00000002]]
# [-0.00268331 -0.0006503 ]
# iterations:   7
# norm of grad: 3.7594580067943285e-07
# endpoint:     [-4.96266414e-07  9.99999627e-01]
#
# --------------------------------------------------
# starting point: [3.8 0.1]
#
# [[  20.78173104  229.08684583]
#  [ 229.08684583 4340.04781563]]
# [ -11.50000175 -433.60217   ]
# [[   9.28660806 -209.62298093]
#  [-209.62298093 7843.10121113]]
# [ -7.7333326  539.57710417]
# [[4.49277687e+00 2.02403306e+02]
#  [2.02403306e+02 1.43983783e+04]]
# [  -6.39394965 -700.39117784]
# [[ 1.31801547e+00 -1.59607398e+02]
#  [-1.59607398e+02  2.44214347e+04]]
# [ -4.86350495 719.13135115]
# [[ 5.05595565e-01 -1.97439842e+01]
#  [-1.97439842e+01  2.13066502e+04]]
# [-2.25109954 82.77734536]
# [[ 5.06218331e-01 -8.82298748e+00]
#  [-8.82298748e+00  4.72140583e+03]]
# [2.59723375e-03 2.15563692e+01]
# [[5.00009566e-01 2.43383688e+00]
#  [2.43383688e+00 4.93194195e+03]]
# [-0.02605259 -0.98532501]
# [[5.00000005e-01 2.00956387e+00]
#  [2.00956387e+00 4.80814043e+03]]
# [-3.74952594e-05 -2.16810003e-02]
# iterations:   8
# norm of grad: 5.453945707250256e-07
# endpoint:     [ 4.00000155e+00 -5.00531356e-07]
#
# --------------------------------------------------
# starting point: [1.9 0.6]
#
# [[ 494.59716581  487.61546172]
#  [ 487.61546172 1192.96266742]]
# [-205.35005419 -650.40054548]
# [[ 1.03355746e+00 -3.45400159e+01]
#  [-3.45400159e+01  1.33714869e+03]]
# [ 0.47662461 42.48485887]
# [[  176.55049296  2303.04747525]
#  [ 2303.04747525 52602.73507055]]
# [  -340.37869409 -15298.69602064]
# [[ 7.55735520e+01 -2.01092770e+03]
#  [-2.01092770e+03  9.28447166e+04]]
# [ -198.59935924 17690.43342301]
# [[3.21358976e+01 1.74707882e+03]
#  [1.74707882e+03 1.63650387e+05]]
# [  -118.61945472 -20421.55638446]
# [[ 1.24633894e+01 -1.45298008e+03]
#  [-1.45298008e+03  2.83240468e+05]]
# [  -70.62783061 22301.69663494]
# [[3.77716380e+00 1.05898665e+03]
#  [1.05898665e+03 4.67241108e+05]]
# [   -41.40986857 -20926.93520444]
# [[ 5.11590770e-01 -2.62630806e+02]
#  [-2.62630806e+02  5.76500156e+05]]
# [ -21.2294396  5720.45459654]
# [[6.42152997e-01 5.00843811e+01]
#  [5.00843811e+01 4.06785627e+03]]
# [  4.40666862 103.97272809]
# [[   4936.35513968 -106989.29022695]
#  [-106989.29022695 4242410.00436743]]
# [ -80931.35803938 6387473.91570359]
# [[1.37950075e+03 8.39261286e+04]
#  [8.39261286e+04 7.18235980e+06]]
# [  -37936.35079637 -6486776.44552663]
# [[ 3.90316024e+03 -1.66663644e+05]
#  [-1.66663644e+05  1.86981637e+07]]
# [  -92298.17800224 20744267.35192537]
# [[1.74622983e+02 5.90225682e+04]
#  [5.90225682e+04 2.48776050e+07]]
# [  -10216.3515985  -8495727.29109786]
# [[ 1.11818942e+03 -2.35621958e+05]
#  [-2.35621958e+05  9.93004069e+07]]
# [  -80512.303859   67699461.79911494]
# [[4.65661287e+02 1.46683306e+05]
#  [1.46683306e+05 1.54932495e+08]]
# [-2.52857450e+04 -5.26840426e+07]
# [[ 1.21809323e+01 -3.39350641e+04]
#  [-3.39350641e+04  1.89080543e+08]]
# [-1.60417473e+03  1.34719517e+07]
# [[2.91038305e+01 1.33150024e+04]
#  [1.33150024e+04 2.58074404e+08]]
# [-6.21654093e+02 -6.18777740e+06]
# [[7.27595761e+00 2.98314262e+02]
#  [2.98314262e+02 2.52186270e+08]]
# [   -456.50859829 -138483.30880865]
# [[7.27596971e+00 3.63797857e+01]
#  [3.63797857e+01 2.18862042e+08]]
# [  -425.06682803 -16354.35325443]
# [[7.27595761e+00 0.00000000e+00]
#  [0.00000000e+00 1.89946724e+08]]
# [ -395.85542982 -1952.3218798 ]
# [[0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.64859892e+08]]
# [-368.65245784 -100.31528655]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[2], line 40
#      38 print(f'starting point: {x_0}')
#      39 print()
# ---> 40 x_fin, p_fin, a_fin, n_iter = newtons_method_hessian_mod(
#      41     x_0, f, grad_f, hess_f, stop_crit=1e-6, print_interval=False, hess_modifier=mod_method)
#      42 result = x_fin[-1]
#      43 print(f'iterations:   {n_iter}')
#
# File ~\Documents\Uni\Numerical Optimization\ss23_numerical_optimisation\1\Phase 2\NM_w_hessian_mod.py:109, in newtons_method_hessian_mod(start_point, f, grad_f, hess_f, stop_crit, print_interval, hess_modifier)
#     107 print(mod_hess)
#     108 print(-grad_f(x_k))
# --> 109 p_k = solve(mod_hess.astype(float), (-grad_f(x_k).astype(float))).reshape(-1)
#     110 a_k = 1
#     111 x_k += a_k * p_k
#
# File <__array_function__ internals>:200, in solve(*args, **kwargs)
#
# File ~\anaconda3\envs\data_science\lib\site-packages\numpy\linalg\linalg.py:386, in solve(a, b)
#     384 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     385 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 386 r = gufunc(a, b, signature=signature, extobj=extobj)
#     388 return wrap(r.astype(result_t, copy=False))
#
# File ~\anaconda3\envs\data_science\lib\site-packages\numpy\linalg\linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %% [markdown]
# ## linear CG

# %%
import funcs as fc
from linear_cg import linear_cg
from steepest_descent import steepest_descent

pd.options.display.max_colwidth = 1000

inputs = [
    (fc.l_f1_grad, np.array([5., -120., 630., -1120.00000001, 630.])),
    (fc.l_f2_grad, np.array([-8.00000052e+00, 5.04000025e+02, -7.56000030e+03, 4.62000015e+04, -1.38600004e+05, 2.16216005e+05,
                 -1.68168004e+05, 5.14800010e+04])),
    (fc.l_f3_grad, np.array([-1.28758021e+01, 1.82700490e+03, -6.35497518e+04, 9.48423728e+05,
                          -7.55539458e+06, 3.58352883e+07, -1.07176657e+08, 2.07239527e+08,
                          -2.58446725e+08, 2.00601048e+08, -8.81030636e+07, 1.67194346e+07])),
    (fc.l_f4_grad, np.array([-3.06198188e+01, 5.79631108e+03, -2.67656855e+05, 5.30590627e+06,
                          -5.62934738e+07, 3.56180768e+08, -1.41454296e+09, 3.54689896e+09,
                          -5.26881741e+09, 3.31570124e+09, 2.23492076e+09, -4.62144407e+09,
                          -4.79904240e+08, 5.96741325e+09, -4.19120773e+09, -4.68358103e+08,
                          1.17802999e+09, 4.13333400e+08, -7.15516924e+08, 1.98562765e+08])),
    (fc.l_f5_grad, np.array([-9.82482439e+00, 1.83726227e+03, -8.40808229e+04, 1.63655657e+06,
                          -1.67132563e+07, 9.84342322e+07, -3.42619774e+08, 6.54384034e+08,
                          -3.64246837e+08, -1.23608428e+09, 3.33110919e+09, -4.11395369e+09,
                          3.61640475e+09, -3.04010905e+09, 2.03383571e+09, -6.12820729e+08,
                          5.54105091e+08, -1.97634656e+09, 2.17304903e+09, 2.29862444e+08,
                          -1.61735957e+09, -5.59274698e+08, 1.42743422e+09, 9.15511460e+08,
                          -4.43132977e+08, -2.73444446e+09, 2.35525831e+09, 5.29596440e+08,
                          -1.25096008e+09, 3.87527105e+08]))
]
for grad_fn, sol in inputs:
    n_dims = sol.shape[0]
    
    x_k, r_k_norm, sol_diff_norm, iteration = linear_cg(grad_fn, np.zeros(shape=n_dims), sol, n_dims)
       
    df_dict = {
        '$$x_k$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_k]) + r'\end{pmatrix}$$', 
        '$$\Vert r_k\ \Vert$$': r_k_norm, 
        '$$\Vert x^* - x_k \Vert$$': sol_diff_norm, 
        'iteration': iteration
    }
    
    df = pd.DataFrame(df_dict, index=[n_dims])
    display(df)

# %% [markdown]
# ### Steepest Descent

# %%
import funcs as fc
from linear_cg import linear_cg
from steepest_descent import steepest_descent

pd.options.display.max_colwidth = 1000

inputs = [
    (fc.l_f1_grad, np.array([5., -120., 630., -1120.00000001, 630.])),
    (fc.l_f2_grad, np.array([-8.00000052e+00, 5.04000025e+02, -7.56000030e+03, 4.62000015e+04, -1.38600004e+05, 2.16216005e+05,
                 -1.68168004e+05, 5.14800010e+04])),
    (fc.l_f3_grad, np.array([-1.28758021e+01, 1.82700490e+03, -6.35497518e+04, 9.48423728e+05,
                          -7.55539458e+06, 3.58352883e+07, -1.07176657e+08, 2.07239527e+08,
                          -2.58446725e+08, 2.00601048e+08, -8.81030636e+07, 1.67194346e+07])),
    (fc.l_f4_grad, np.array([-3.06198188e+01, 5.79631108e+03, -2.67656855e+05, 5.30590627e+06,
                          -5.62934738e+07, 3.56180768e+08, -1.41454296e+09, 3.54689896e+09,
                          -5.26881741e+09, 3.31570124e+09, 2.23492076e+09, -4.62144407e+09,
                          -4.79904240e+08, 5.96741325e+09, -4.19120773e+09, -4.68358103e+08,
                          1.17802999e+09, 4.13333400e+08, -7.15516924e+08, 1.98562765e+08])),
    (fc.l_f5_grad, np.array([-9.82482439e+00, 1.83726227e+03, -8.40808229e+04, 1.63655657e+06,
                          -1.67132563e+07, 9.84342322e+07, -3.42619774e+08, 6.54384034e+08,
                          -3.64246837e+08, -1.23608428e+09, 3.33110919e+09, -4.11395369e+09,
                          3.61640475e+09, -3.04010905e+09, 2.03383571e+09, -6.12820729e+08,
                          5.54105091e+08, -1.97634656e+09, 2.17304903e+09, 2.29862444e+08,
                          -1.61735957e+09, -5.59274698e+08, 1.42743422e+09, 9.15511460e+08,
                          -4.43132977e+08, -2.73444446e+09, 2.35525831e+09, 5.29596440e+08,
                          -1.25096008e+09, 3.87527105e+08]))
]

linear_cg_dfs = []
steepest_descent_dfs = []

for grad_fn, sol in inputs:
    n_dims = sol.shape[0]
    
    x_k, r_k_norm, sol_diff_norm, iteration = steepest_descent(
        grad_fn, 
        np.zeros(shape=n_dims), 
        sol, 
        n_dims,
        max_iter=int(1.5e6)
    )
       
    df_dict = {
        '$$x_k$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_k]) + r'\end{pmatrix}$$', 
        '$$\Vert r_k\ \Vert$$': r_k_norm, 
        '$$\Vert x^* - x_k \Vert$$': sol_diff_norm, 
        'iteration': iteration
    }
    
    df = pd.DataFrame(df_dict, index=[n_dims])
    display(df)

# %% [markdown]
# TODO: explanation why no convergy

# %% [markdown]
# ## Nonlinear CG

# %% [markdown]
# ### Fletcher-Reevers

# %%
from fr_cg import fr_cg
import funcs as fc

inputs_rosenbrock = [
    (fc.rosenbrock, fc.rosenbrock_gradient, np.array([1.2, 1.2]), np.array([1., 1.])),
    (fc.rosenbrock, fc.rosenbrock_gradient, np.array([-1.2, 1.]), np.array([1., 1.])),
    (fc.rosenbrock, fc.rosenbrock_gradient, np.array([0.2, 0.8]), np.array([1., 1.])),
]
rosenbrock_dicts = []

for fn, fn_grad_orig, x_0, x_star in inputs_rosenbrock:
    
    fn_grad_approx = lambda x: approximate_gradient(fn, x)
    
    for fn_grad, is_approx in [(fn_grad_orig, False), (fn_grad_approx, True)]:
        x_k, r_k_norm, sol_diff_norm, iteration = fr_cg(fn, fn_grad, x_0, x_star)
        rosenbrock_dicts.append({
            'approximation?': 'Actual Gradient' if not is_approx else 'Approx. Gradient',
            '$$x_0$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_0]) + r'\end{pmatrix}$$',
            '$$x_k$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_k]) + r'\end{pmatrix}$$', 
            '$$\Vert r_k\ \Vert$$': r_k_norm, 
            '$$\Vert x^* - x_k \Vert$$': sol_diff_norm, 
            'iteration': iteration
        })

display(pd.DataFrame(rosenbrock_dicts))

# %%
from fr_cg import fr_cg
import funcs as fc

inputs_nl_f = [
    (fc.nl_f, fc.nl_f_grad, np.array([-0.2, 1.2]), np.array([0., 1.])),
    (fc.nl_f, fc.nl_f_grad, np.array([3.8, 0.1]), np.array([4., 0.])),
    (fc.nl_f, fc.nl_f_grad, np.array([1.9, 0.6]), np.array([0., 1.])),
]
nl_f_dicts = []

for fn, fn_grad_orig, x_0, x_star in inputs_nl_f:
    
    fn_grad_approx = lambda x: approximate_gradient(fn, x)
    
    for fn_grad, is_approx in [(fn_grad_orig, False), (fn_grad_approx, True)]:
        x_k, r_k_norm, sol_diff_norm, iteration = fr_cg(fn, fn_grad, x_0, x_star)
        nl_f_dicts.append({
            'approximation?': 'Actual Gradient' if not is_approx else 'Approx. Gradient',
            '$$x_0$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_0]) + r'\end{pmatrix}$$',
            '$$x_k$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_k]) + r'\end{pmatrix}$$', 
            '$$\Vert r_k\ \Vert$$': r_k_norm, 
            '$$\Vert x^* - x_k \Vert$$': sol_diff_norm, 
            'iteration': iteration
        })

display(pd.DataFrame(nl_f_dicts))

# %% [markdown]
# ### Polak-Ribiere

# %%
from pr_cg import pr_cg
import funcs as fc

inputs_rosenbrock = [
    (fc.rosenbrock, fc.rosenbrock_gradient, np.array([1.2, 1.2]), np.array([1., 1.])),
    (fc.rosenbrock, fc.rosenbrock_gradient, np.array([-1.2, 1.]), np.array([1., 1.])),
    (fc.rosenbrock, fc.rosenbrock_gradient, np.array([0.2, 0.8]), np.array([1., 1.])),
]
rosenbrock_dicts = []

for fn, fn_grad_orig, x_0, x_star in inputs_rosenbrock:
    
    fn_grad_approx = lambda x: approximate_gradient(fn, x)
    
    for fn_grad, is_approx in [(fn_grad_orig, False), (fn_grad_approx, True)]:
        x_k, r_k_norm, sol_diff_norm, iteration = pr_cg(fn, fn_grad, x_0, x_star)
        rosenbrock_dicts.append({
            'approximation?': 'Actual Gradient' if not is_approx else 'Approx. Gradient',
            '$$x_0$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_0]) + r'\end{pmatrix}$$',
            '$$x_k$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_k]) + r'\end{pmatrix}$$', 
            '$$\Vert r_k\ \Vert$$': r_k_norm, 
            '$$\Vert x^* - x_k \Vert$$': sol_diff_norm, 
            'iteration': iteration
        })

display(pd.DataFrame(rosenbrock_dicts))

# %%
from pr_cg import pr_cg
import funcs as fc

inputs_nl_f = [
    (fc.nl_f, fc.nl_f_grad, np.array([-0.2, 1.2]), np.array([0., 1.])),
    (fc.nl_f, fc.nl_f_grad, np.array([3.8, 0.1]), np.array([4., 0.])),
    (fc.nl_f, fc.nl_f_grad, np.array([1.9, 0.6]), np.array([0., 1.])),
]
nl_f_dicts = []

for fn, fn_grad_orig, x_0, x_star in inputs_nl_f:
    
    fn_grad_approx = lambda x: approximate_gradient(fn, x)
    
    for fn_grad, is_approx in [(fn_grad_orig, False), (fn_grad_approx, True)]:
        x_k, r_k_norm, sol_diff_norm, iteration = pr_cg(fn, fn_grad, x_0, x_star)
        nl_f_dicts.append({
            'approximation?': 'Actual Gradient' if not is_approx else 'Approx. Gradient',
            '$$x_0$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_0]) + r'\end{pmatrix}$$',
            '$$x_k$$': r'$$\begin{pmatrix}' + r' \\ '.join([str(round(d, 2)) for d in x_k]) + r'\end{pmatrix}$$', 
            '$$\Vert r_k\ \Vert$$': r_k_norm, 
            '$$\Vert x^* - x_k \Vert$$': sol_diff_norm, 
            'iteration': iteration
        })

display(pd.DataFrame(nl_f_dicts))

# %% [markdown]
# ## QN methods

# %%
import math
from qn.optimization import bfgs_method, sr1_method
from qn.problems import rosenbrock, rosenbrock_grad, rosenbrock_starting_points, rosenbrock_solutions
from qn.problems import function_2, function_2_grad, function_2_starting_points, function_2_solutions

# %%
def perform_QN(method, f, grad_orig, starting_points, sol_points, max_iter=100, epsilon=1e-6):
    for i, sp in enumerate(starting_points):
        print(f"Solving Problem-{i+1}, Starting Point: {sp}")
        x0 = np.array(sp)
        
        grad_approx = lambda x: approximate_gradient(f, x)
        
        for grad, is_approx in [(grad_orig, False), (grad_approx, True)]:
            x_opt, gnorm, num_iters = method(f, grad, x0, max_iter, epsilon)

            print(f"Optimal solution - {'with' if is_approx else 'without'} gradient approximation:")
            print(f"x = {x_opt}")
            print(f"norm of grad = {gnorm}")
            print(f"distance = {math.dist(x_opt, sol_points[i])}")
            print(f"Number of iterations: {num_iters}\n")

# %%
print("<Quasi Newton Method for the Rosenbrock function>")
print("BFGS"+"-"*50)
perform_QN(bfgs_method, rosenbrock, rosenbrock_grad, rosenbrock_starting_points, rosenbrock_solutions)
print("SR1-" + "-"*50)
perform_QN(sr1_method, rosenbrock, rosenbrock_grad, rosenbrock_starting_points, rosenbrock_solutions)
# Out:
# <Quasi Newton Method for the Rosenbrock function>
# BFGS--------------------------------------------------
# Solving Problem-1, Starting Point: (1.2, 1.2)
# Optimal solution - without gradient approximation:
# x = [1. 1.]
# norm of grad = 3.9172139696307626e-08
# distance = 1.9566929546729326e-09
# Number of iterations: 11
#
# Optimal solution - with gradient approximation:
# x = [0.99969965 0.99939889]
# norm of grad = 2.526352843790415e-08
# distance = 0.0006719681680405487
# Number of iterations: 11
#
# Solving Problem-2, Starting Point: (-1.2, 1)
# Optimal solution - without gradient approximation:
# x = [1.00000001 1.00000001]
# norm of grad = 1.0506595642943314e-07
# distance = 1.4444376803793241e-08
# Number of iterations: 34
#
# Optimal solution - with gradient approximation:
# x = [0.99969965 0.99939889]
# norm of grad = 5.347668022084e-08
# distance = 0.0006719678084843039
# Number of iterations: 33
#
# Solving Problem-3, Starting Point: (0.2, 0.8)
# Optimal solution - without gradient approximation:
# x = [1. 1.]
# norm of grad = 1.9771719277570665e-08
# distance = 2.4444794081871138e-11
# Number of iterations: 21
#
# Optimal solution - with gradient approximation:
# x = [0.99969968 0.99939895]
# norm of grad = 4.150076459329473e-07
# distance = 0.0006719041821309491
# Number of iterations: 20
#
# SR1---------------------------------------------------
# Solving Problem-1, Starting Point: (1.2, 1.2)
# Optimal solution - without gradient approximation:
# x = [1. 1.]
# norm of grad = 8.804632601024593e-08
# distance = 1.9978059250268723e-09
# Number of iterations: 12
#
# Optimal solution - with gradient approximation:
# x = [0.99969965 0.99939889]
# norm of grad = 3.883668328018438e-11
# distance = 0.0006719697717165714
# Number of iterations: 15
#
# Solving Problem-2, Starting Point: (-1.2, 1)
# Optimal solution - without gradient approximation:
# x = [1. 1.]
# norm of grad = 7.706622491884477e-10
# distance = 1.4586755524260767e-09
# Number of iterations: 41
#
# Optimal solution - with gradient approximation:
# x = [0.99969965 0.99939889]
# norm of grad = 4.4377034248193516e-08
# distance = 0.0006719717960262243
# Number of iterations: 47
#
# Solving Problem-3, Starting Point: (0.2, 0.8)
# Optimal solution - without gradient approximation:
# x = [0.99999978 0.99999956]
# norm of grad = 5.734284088253337e-07
# distance = 4.87086979871155e-07
# Number of iterations: 22
#
# Optimal solution - with gradient approximation:
# x = [0.99970033 0.99940026]
# norm of grad = 9.657136365804868e-07
# distance = 0.0006704381056602264
# Number of iterations: 26

# %%
print("<Quasi Newton Method for the second Function>")
print("BFGS"+"-"*50)
perform_QN(bfgs_method, function_2, function_2_grad, function_2_starting_points, function_2_solutions)
print("SR1-" + "-"*50)
perform_QN(sr1_method, function_2, function_2_grad, function_2_starting_points, function_2_solutions)
# Out:
# <Quasi Newton Method for the second Function>
# BFGS--------------------------------------------------
# Solving Problem-1, Starting Point: (-0.2, 1.2)
# Optimal solution - without gradient approximation:
# x = [ 4.000000e+00 -3.468578e-11]
# norm of grad = 1.7076990231341392e-07
# distance = 1.9989648552914663e-09
# Number of iterations: 11
#
# Optimal solution - with gradient approximation:
# x = [ 4.00000150e+00 -5.00660451e-07]
# norm of grad = 1.7580857129365691e-07
# distance = 1.5811791399278446e-06
# Number of iterations: 11
#
# Solving Problem-2, Starting Point: (3.8, 0.1)
# Optimal solution - without gradient approximation:
# x = [4.00000000e+00 2.99090477e-13]
# norm of grad = 1.5261767933646526e-09
# distance = 4.3992493848322424e-11
# Number of iterations: 8
#
# Optimal solution - with gradient approximation:
# x = [ 4.00000150e+00 -5.00624432e-07]
# norm of grad = 1.617287441676314e-09
# distance = 1.583179672288559e-06
# Number of iterations: 8
#
# Solving Problem-3, Starting Point: (1.9, 0.6)
# Optimal solution - without gradient approximation:
# x = [ 4.00000000e+00 -2.61907483e-13]
# norm of grad = 1.0721881353034358e-09
# distance = 9.40362549156254e-11
# Number of iterations: 21
#
# Optimal solution - with gradient approximation:
# x = [ 4.00000154e+00 -5.00531425e-07]
# norm of grad = 5.193777842342006e-07
# distance = 1.6165257041851976e-06
# Number of iterations: 20
#
# SR1---------------------------------------------------
# Solving Problem-1, Starting Point: (-0.2, 1.2)
# Optimal solution - without gradient approximation:
# x = [4.00000000e+00 6.00658256e-12]
# norm of grad = 2.8910434546734335e-08
# distance = 1.6520131455590986e-11
# Number of iterations: 9
#
# Optimal solution - with gradient approximation:
# x = [ 4.00000150e+00 -5.00618743e-07]
# norm of grad = 2.894536313161538e-08
# distance = 1.5831684044610594e-06
# Number of iterations: 9
#
# Solving Problem-2, Starting Point: (3.8, 0.1)
# Optimal solution - without gradient approximation:
# x = [ 3.99999999e+00 -1.99645091e-11]
# norm of grad = 1.1426748335485134e-07
# distance = 9.093042919697556e-09
# Number of iterations: 7
#
# Optimal solution - with gradient approximation:
# x = [ 4.00000149e+00 -5.00643497e-07]
# norm of grad = 1.0846806154386683e-07
# distance = 1.5744971638166182e-06
# Number of iterations: 7
#
# Solving Problem-3, Starting Point: (1.9, 0.6)
# Optimal solution - without gradient approximation:
# x = [-3.70872618e-10  1.00000000e+00]
# norm of grad = 1.1154428248553136e-07
# distance = 4.123105625966356
# Number of iterations: 26
#
# Optimal solution - with gradient approximation:
# x = [-4.94746428e-07  9.99999604e-01]
# norm of grad = 8.022631256517767e-07
# distance = 4.1231060095297885
# Number of iterations: 32

# %% [markdown]
# ## derivatives approximation

# %%
from approx_gradient import rosenbrock_function,\
                            rosenbrock_function_g,\
                            rosenbrock_function_h,\
                            function1, function1_g,\
                            function1_h,\
                            approximate_gradient, approximate_hessian

rosenbrock_function_sp = np.array([[1.2, 1.2], [-1.2, 1], [0.2, 0.8]])
function1_sp = np.array([[-0.2, 1.2], [3.8, 0.1], [1.9, 0.6]])

for i in range(3):
    real_ros_g = rosenbrock_function_g(rosenbrock_function_sp[i])
    appr_ros_g = approximate_gradient(rosenbrock_function, rosenbrock_function_sp[i])
    real_ros_h = rosenbrock_function_h(rosenbrock_function_sp[i])
    appr_ros_h = approximate_hessian(rosenbrock_function, rosenbrock_function_sp[i])
    print(f"Rosenbrock-Function at {rosenbrock_function_sp[i]}: {rosenbrock_function(rosenbrock_function_sp[i])}")
    print(f"Real Gradient of Rosenbrock-Function at {rosenbrock_function_sp[i]}: {real_ros_g}")
    print(f"Approximated Gradient of Rosenbrock-Function at {rosenbrock_function_sp[i]}: {appr_ros_g}")
    print(f"Norm: {np.linalg.norm(real_ros_g - appr_ros_g)}")
    print(f"Real Hessian of Rosenbrock-Function at {rosenbrock_function_sp[i]}:\n{real_ros_h}")
    print(f"Approximated Hessian of Rosenbrock-Function at {rosenbrock_function_sp[i]}:\n{appr_ros_h}")
    print(f"Norm: {np.linalg.norm(real_ros_h - appr_ros_h)}")
    print()
    
    real_f1_g = function1_g(function1_sp[i])
    appr_f1_g = approximate_gradient(function1, function1_sp[i])
    real_f1_h = function1_h(function1_sp[i])
    appr_f1_h = approximate_hessian(function1, function1_sp[i])
    print(f"Function1 at {function1_sp[i]}: {function1(function1_sp[i])}")
    print(f"Real Gradient of Function1 at {function1_sp[i]}: {real_f1_g}")
    print(f"Approximated Gradient of Function1 at {function1_sp[i]}: {appr_f1_g}")
    print(f"Norm: {np.linalg.norm(real_f1_g - appr_f1_g)}")
    print(f"Real Hessian of Function1 at {function1_sp[i]}:\n{real_f1_h}")
    print(f"Approximated Hessian of Function1 at {function1_sp[i]}:\n{appr_f1_h}")
    print(f"Norm: {np.linalg.norm(real_f1_h - appr_f1_h)}")
    print("="*80)
# Out:
# Rosenbrock-Function at [1.2 1.2]: 5.8
# Real Gradient of Rosenbrock-Function at [1.2 1.2]: [115.6 -48. ]
# Approximated Gradient of Rosenbrock-Function at [1.2 1.2]: [115.60062499 -47.9999    ]
# Norm: 0.0006329373981467745
# Real Hessian of Rosenbrock-Function at [1.2 1.2]:
# [[1250. -480.]
#  [-480.  200.]]
# Approximated Hessian of Rosenbrock-Function at [1.2 1.2]:
# [[1250.00054751 -480.00003972]
#  [-480.00003972  200.00001655]]
# Norm: 0.0005506367033515529
#
# Function1 at [-0.2  1.2]: 8.73
# Real Gradient of Function1 at [-0.2  1.2]: [-86.1  15.6]
# Approximated Gradient of Function1 at [-0.2  1.2]: [-86.09978375  15.60001   ]
# Norm: 0.00021648224992243072
# Real Hessian of Function1 at [-0.2  1.2]:
# [[ 432.5 -142. ]
#  [-142.    20. ]]
# Approximated Hessian of Function1 at [-0.2  1.2]:
# [[ 432.50025783 -142.00018938]
#  [-142.00018938   20.00000165]]
# Norm: 0.0003717689734517968
# ================================================================================
# Rosenbrock-Function at [-1.2  1. ]: 24.199999999999996
# Real Gradient of Rosenbrock-Function at [-1.2  1. ]: [-215.6  -88. ]
# Approximated Gradient of Rosenbrock-Function at [-1.2  1. ]: [-215.59933498  -87.99989999]
# Norm: 0.0006724987745917052
# Real Hessian of Rosenbrock-Function at [-1.2  1. ]:
# [[1330.  480.]
#  [ 480.  200.]]
# Approximated Hessian of Rosenbrock-Function at [-1.2  1. ]:
# [[1330.00099822  480.00181607]
#  [ 480.00181607  200.0017929 ]]
# Norm: 0.0032874296967387987
#
# Function1 at [3.8 0.1]: 21.67
# Real Gradient of Function1 at [3.8 0.1]: [ 11.5 433.6]
# Approximated Gradient of Function1 at [3.8 0.1]: [ 11.50000175 433.60217   ]
# Norm: 0.0021699991434765377
# Real Hessian of Function1 at [3.8 0.1]:
# [[3.50e+00 2.30e+02]
#  [2.30e+02 4.34e+03]]
# Approximated Hessian of Function1 at [3.8 0.1]:
# [[3.49942297e+00 2.30000907e+02]
#  [2.30000907e+02 4.33999947e+03]]
# Norm: 0.0015029789994869085
# ================================================================================
# Rosenbrock-Function at [0.2 0.8]: 58.4
# Real Gradient of Rosenbrock-Function at [0.2 0.8]: [-62.4 152. ]
# Approximated Gradient of Rosenbrock-Function at [0.2 0.8]: [-62.40013499 152.00010001]
# Norm: 0.00016800289712164617
# Real Hessian of Rosenbrock-Function at [0.2 0.8]:
# [[-270.  -80.]
#  [ -80.  200.]]
# Approximated Hessian of Rosenbrock-Function at [0.2 0.8]:
# [[-269.99380509  -80.00178298]
#  [ -80.00178298  200.00356926]]
# Norm: 0.00758119613075792
#
# Function1 at [1.9 0.6]: 194.96249999999998
# Real Gradient of Function1 at [1.9 0.6]: [205.35 650.4 ]
# Approximated Gradient of Function1 at [1.9 0.6]: [205.35005419 650.40054548]
# Norm: 0.0005481663576974557
# Real Hessian of Function1 at [1.9 0.6]:
# [[ 108.5  686. ]
#  [ 686.  1091. ]]
# Approximated Hessian of Function1 at [1.9 0.6]:
# [[ 108.4856649   686.02190595]
#  [ 686.02190595 1091.00994905]]
# Norm: 0.035555871747700855
# ================================================================================
